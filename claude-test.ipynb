# %%
"""Preparation"""
# !pip install anthropic
import anthropic
import os
# !pip install python-dotenv
from dotenv import load_dotenv
load_dotenv()

# %%
# Define the directory containing the JSON files
directory = 'dataProcess/data'

# Initialize an empty list to hold the JSON strings
json_strings = []

# Iterate over all files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.json'):
        filepath = os.path.join(directory, filename)
        with open(filepath, 'r') as file:
            # Read the file content and append to the list
            json_strings.append(file.read())

# Now json_strings contains all the JSON file contents as strings
# for i, json_str in enumerate(json_strings):
#     print(f"Content of file {i+1}: {json_str[:100]}...")  # Print first 100 characters of each file for verification

print(json_strings[0])
print(type(json_strings[0]))
# Out:
# {
#     "industry": "e-commerce platforms",
#     "bmc": {
#         "key_partners": [
#             {
#                 "type": "Product suppliers",
#                 "examples": ["Kole Imports", "DollarDays"]
#             },
#             {
#                 "type": "Payment processors",
#                 "examples": ["PayPal", "Stripe", "Square"]
#             },
#             {
#                 "type": "Logistics and delivery partners",
#                 "examples": ["FedEx", "UPS", "DHL"]
#             },
#             {
#                 "type": "Marketing and advertising agencies",
#                 "examples": ["Thrive Internet Marketing Agency", "LYFE Marketing", "Wpromote"]
#             }
#         ],
#         "key_activities": [
#             "Platform development and maintenance",
#             "Merchant onboarding",
#             "Customer acquisition",
#             "Payment processing",
#             "Order fulfillment"
#         ],
#         "key_resources": [
#             "E-commerce platform",
#             "Technology infrastructure",
#             "Development team",
#             "Customer support team",
#             "Marketing and sales team"
#         ],
#         "value_propositions": [
#             "Wide variety of products",
#             "User-friendly shopping experience",
#             "Secure payment processing",
#             "Fast and reliable delivery",
#             "Customer reviews and ratings"
#         ],
#         "customer_relationships": [
#             "Customer support",
#             "Loyalty programs",
#             "Personalized recommendations",
#             "Community engagement",
#             "Social media interaction"
#         ],
#         "channels": [
#             "Website",
#             "Mobile app",
#             "Email marketing",
#             "Social media",
#             "Affiliate networks"
#         ],
#         "customer_segments": [
#             "Individual consumers",
#             "Small and medium-sized businesses",
#             "Large enterprises",
#             "Niche markets",
#             "International customers"
#         ],
#         "cost_structure": [
#             "Platform development and maintenance costs",
#             "Marketing and advertising expenses",
#             "Payment processing fees",
#             "Logistics and delivery costs",
#             "Customer service costs"
#         ],
#         "revenue_streams": [
#             "Transaction fees",
#             "Subscription fees",
#             "Advertising revenue",
#             "Premium services",
#             "Affiliate commissions"
#         ]
#     }
# }
# <class 'str'>

# %%
import anthropic

prompt = "I want to start a company in mail delivery. Generate a Business Model Canvas for my business."

client = anthropic.Anthropic(
    # defaults to os.environ.get("ANTHROPIC_API_KEY")
    api_key="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",
)
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=2048,
    messages=[
                        {"role": "system", "content": "You are a professional business consultant. You are helping a client to "
                                                        "build a business model canvas (BMC).",
                                                        "role": "user", "content": prompt + "Here are some examples of industry and BMC:" + json_strings[0] + json_strings[1] + "\n Note: You should return ONLY a JSON dictionary for "
                                                        "each of the keys: key_partners, key_activities, key_resources, "
                                                        "value_proposition, customer_relationship, channels, customer_segments, "
                                                        "cost_structure, revenue_streams according to the information provided. "
                                                        "Each key should be a list of strings. The client will provide you with the "
                                                        "information needed to generate the BMC. You should generate the BMC based "
                                                        "on the information provided by the client. If the client asks you to modify "
                                                        "a specific key, you should modify that key and keep everything else "
                                                        "unchanged. "}
                    ]
)
#print(message.content)
response = "\n".join(block.text for block in message.content)
print("\n".join(block.text for block in message.content))
# Out:
# Here's a Business Model Canvas for your mail delivery company in JSON format:
#
# {
#   "key_partners": [
#     "Postal services",
#     "Logistics companies",
#     "Vehicle manufacturers",
#     "Packaging suppliers",
#     "Technology providers"
#   ],
#   "key_activities": [
#     "Package collection",
#     "Sorting and processing",
#     "Transportation and delivery",
#     "Route optimization",
#     "Customer service"
#   ],
#   "key_resources": [
#     "Delivery fleet",
#     "Sorting facilities",
#     "Tracking technology",
#     "Skilled workforce",
#     "Customer database"
#   ],
#   "value_propositions": [
#     "Fast and reliable delivery",
#     "Competitive pricing",
#     "Real-time package tracking",
#     "Flexible delivery options",
#     "Excellent customer service"
#   ],
#   "customer_relationships": [
#     "Self-service online portal",
#     "24/7 customer support",
#     "Loyalty programs",
#     "Personalized services",
#     "Regular communication"
#   ],
#   "channels": [
#     "Company website",
#     "Mobile app",
#     "Local offices",
#     "Customer service hotline",
#     "Social media"
#   ],
#   "customer_segments": [
#     "Individual consumers",
#     "Small businesses",
#     "E-commerce companies",
#     "Corporate clients",
#     "Government agencies"
#   ],
#   "cost_structure": [
#     "Fleet maintenance and fuel",
#     "Employee salaries",
#     "Facility operations",
#     "Technology infrastructure",
#     "Marketing and advertising"
#   ],
#   "revenue_streams": [
#     "Delivery fees",
#     "Express delivery surcharges",
#     "Bulk shipping discounts",
#     "Value-added services",
#     "Insurance fees"
#   ]
# }

# %%
import json
type(response)
json.loads(response)
# Out:
# {'key_partners': ['Ingredient suppliers',
#   'Packaging manufacturers',
#   'Delivery service providers',
#   'Local farmers',
#   'Tech companies'],
#  'key_activities': ['Product development',
#   'Quality control',
#   'Marketing and branding',
#   'Supply chain management',
#   'Customer service'],
#  'key_resources': ['Proprietary recipes',
#   'Food production facilities',
#   'Distribution network',
#   'Brand reputation',
#   'Skilled workforce'],
#  'value_proposition': ['Convenient meal solutions',
#   'Customizable food options',
#   'Healthy and nutritious meals',
#   'Eco-friendly packaging',
#   'Unique flavor combinations'],
#  'customer_relationship': ['Personalized meal recommendations',
#   'Loyalty program',
#   '24/7 customer support',
#   'Social media engagement',
#   'Community events'],
#  'channels': ['E-commerce website',
#   'Mobile app',
#   'Grocery store partnerships',
#   'Food delivery platforms',
#   'Direct mail'],
#  'customer_segments': ['Busy professionals',
#   'Health-conscious consumers',
#   'Millennials and Gen Z',
#   'Families with children',
#   'Fitness enthusiasts'],
#  'cost_structure': ['Ingredient costs',
#   'Production and packaging',
#   'Marketing and advertising',
#   'Employee salaries',
#   'Technology infrastructure'],
#  'revenue_streams': ['Subscription meal plans',
#   'One-time purchases',
#   'Upselling premium ingredients',
#   'Partnerships with health insurance companies',
#   'Cooking classes and workshops']}

# %%
from collections import deque
history = deque([], maxlen=5)
history.append([1])
print(type(history))
print(len(history))
print(str(list(history)))
# Out:
# <class 'collections.deque'>
# 1
# [[1]]

# %%
import anthropic


client = anthropic.Anthropic(
    # defaults to os.environ.get("ANTHROPIC_API_KEY")
    api_key="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",
)
message = client.messages.create(
    model="claude-3-5-sonnet-20240620",
    max_tokens=2048,
    messages=[{"role": "system", "content": "You are an AI assistant."},
                {"role": "user", "content": "Hello!"}      
            ]
)
#print(message.content)
response = "\n".join(block.text for block in message.content)
print("\n".join(block.text for block in message.content))
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[10], line 8
#       1 import anthropic
#       4 client = anthropic.Anthropic(
#       5     # defaults to os.environ.get("ANTHROPIC_API_KEY")
#       6     api_key="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",
#       7 )
# ----> 8 message = client.messages.create(
#       9     model="claude-3-5-sonnet-20240620",
#      10     max_tokens=2048,
#      11     messages=[{"role": "system", "content": "You are an AI assistant."},
#      12                 {"role": "user", "content": "Hello!"}
#      13             ]
#      14 )
#      15 #print(message.content)
#      16 response = "\n".join(block.text for block in message.content)
#
# File /opt/homebrew/lib/python3.10/site-packages/anthropic/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/anthropic/resources/messages.py:904, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     870 @required_args(["max_tokens", "messages", "model"], ["max_tokens", "messages", "model", "stream"])
#     871 def create(
#     872     self,
#    (...)
#     902     timeout: float | httpx.Timeout | None | NotGiven = 600,
#     903 ) -> Message | Stream[RawMessageStreamEvent]:
# --> 904     return self._post(
#     905         "/v1/messages",
#     906         body=maybe_transform(
#     907             {
#     908                 "max_tokens": max_tokens,
#     909                 "messages": messages,
#     910                 "model": model,
#     911                 "metadata": metadata,
#     912                 "stop_sequences": stop_sequences,
#     913                 "stream": stream,
#     914                 "system": system,
#     915                 "temperature": temperature,
#     916                 "tool_choice": tool_choice,
#     917                 "tools": tools,
#     918                 "top_k": top_k,
#     919                 "top_p": top_p,
#     920             },
#     921             message_create_params.MessageCreateParams,
#     922         ),
#     923         options=make_request_options(
#     924             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     925         ),
#     926         cast_to=Message,
#     927         stream=stream or False,
#     928         stream_cls=Stream[RawMessageStreamEvent],
#     929     )
#
# File /opt/homebrew/lib/python3.10/site-packages/anthropic/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/homebrew/lib/python3.10/site-packages/anthropic/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File /opt/homebrew/lib/python3.10/site-packages/anthropic/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages: Unexpected role "system". The Messages API accepts a top-level `system` parameter, not "system" as an input message role.'}}

# %%
print("123"+str([1,2]))
# Out:
# 123[1, 2]
